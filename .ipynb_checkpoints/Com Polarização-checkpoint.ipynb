# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Scripts.Individual import Individual
from Scripts.Parameters import mu, m, pa
from Scripts.Polarity import polarity
from Scripts.Memory import initialize_memory, probability_distribution, A
from Scripts.Model import Model, evaluateModel, simulate
from Scripts.Entropy import empirical_entropy, JSD
from Scripts.Types import List
# from multiprocessing import Pool
from time import time

import numpy as np
import matplotlib.pyplot as plt
import random
import pickle
from copy import deepcopy

seed = 42

# %%
def list_sum(L1, L2):
    return [L1[k] + L2[k] for k in range(len(L1))]

def mean_lists(L: List[List]) -> List:
    # 1. soma todas as listas
    L0 = L[0]
    for L1 in L[1:]:
        L0 = list_sum(L0, L1)
    
    # 2. divide pelo número de listas
    N = len(L)
    for k in range(len(L0)):
        L0[k] = L0[k]/N
        
    return L0

# %%
def is_salient(code, P):
    return P[code] == max(P.values())

def is_in(code, P):
    return P[code] == 0

def compute_opinion_spread(M):
    D = deepcopy(A)
    for u in M.G.nodes():
        u_info = M.indInfo(u)
        for code in D.keys():
            if is_in(code, u_info.P):
                D[code] += 1
                
    N = len(M.G)
    for code in D.keys():
        D[code] = D[code]/N
        
    return D

def compute_opinion_fragmentation(M):
    D = deepcopy(A)
    for u in M.G.nodes():
        u_info = M.indInfo(u)
        for code in D.keys():
            if is_salient(code, u_info.P):
                D[code] += 1
                
    N = len(M.G)
    for code in D.keys():
        D[code] = D[code]/N
    
    return D

# %%
kappa = 10
num_repetitions = 5
seeds = [random.randint(1, 100) for i in range(num_repetitions)]
proportions = [(0.5, 0.5), (0.6, 0.4), (0.7, 0.3), (0.8, 0.2), (0.9, 0.1), (1.0, 0.0)]
# alpha = 0.5          # Proportion of individuals with tendency to increase polarity
# omega = 0.5          # Proportion of individuals with tendency to lower polarity
lambd = 10            # Polarization coefficient

T = 500

gamma = 1         # Confidence factor

H = {str(prop):None for prop in proportions}
pi = {str(prop):None for prop in proportions}
info_dist_stats = {str(prop):{code:[] for code in A.keys()} for prop in proportions}
N = 500

for alpha, omega in proportions:
    
    print("Inicializando o modelo com os parâmetros:")
    print("N = {} - pa = {} - mu = {} - m = {} - kappa = {} - lambda = {} - alpha = {} - omega = {} - gamma = {}".format(N, pa, mu, m, kappa, lambd, alpha, omega, gamma))
    model = Model(N, pa, mu, m, kappa, lambd, alpha, omega, gamma, 0, False)
    
    H[str((alpha, omega))] = []
    pi[str((alpha, omega))] = []
    D = deepcopy(A)
    for code in D.keys():
        D[code] = []
    
    for rep in range(num_repetitions):
        H_rep_temp    = []
        Pi_rep_temp   = []
        # Especifica um valor inicial para o gerador de números pseudo-aleatórios e inicializa/reiniciar o modelo com esse gerador.
        seed = seeds[rep]
        model.seed = seed
        model.initialize_model_info()
        
        print("Iniciando Repetição N. {}".format(rep))
        elapsedTime = 0
        for i in range(T):
            elapsedTime += simulate(model)
            H_rep_temp.append(model.H)
            Pi_rep_temp.append(model.pi)
            D_temp = compute_opinion_fragmentation(model)
            for code in D.keys():
                D[code].append(D_temp[code])
            
        # Apende aos dados vinculados ao parâmetro "k" os valores de todas as repetições
        print("Finalizada a Repetição N. {} em {} segundos.".format(rep, elapsedTime))
        H[str((alpha, omega))].append(H_rep_temp)
        pi[str((alpha, omega))].append(Pi_rep_temp)
        for code in D.keys():   
            info_dist_stats[str((alpha, omega))][code].append(D[code])
    
# Tira a média das simulações para cada k
for prop in proportions:
    H[str(prop)] = mean_lists(H[str(prop)])
    pi[str(prop)] = mean_lists(pi[str(prop)])
    for code in info_dist_stats[str(prop)].keys():
        info_dist_stats[str(prop)][code] = mean_lists(info_dist_stats[str(prop)][code])
# Out:
# Inicializando o modelo com os parâmetros:
# N = 500 - pa = 2 - mu = 360 - m = 5 - kappa = 10 - lambda = 10 - alpha = 0.5 - omega = 0.5 - gamma = 1
# Iniciando Repetição N. 0
# Finalizada a Repetição N. 0 em 2.84486233393351 segundos.
# Iniciando Repetição N. 1
# Finalizada a Repetição N. 1 em 2.812279184659324 segundos.
# Iniciando Repetição N. 2
# Finalizada a Repetição N. 2 em 2.8471983075141893 segundos.
# Iniciando Repetição N. 3
# Finalizada a Repetição N. 3 em 2.912819449106853 segundos.
# Iniciando Repetição N. 4
# Finalizada a Repetição N. 4 em 2.884556130568184 segundos.
# Inicializando o modelo com os parâmetros:
# N = 500 - pa = 2 - mu = 360 - m = 5 - kappa = 10 - lambda = 10 - alpha = 0.6 - omega = 0.4 - gamma = 1
# Iniciando Repetição N. 0
# Finalizada a Repetição N. 0 em 2.867674044768017 segundos.
# Iniciando Repetição N. 1
# Finalizada a Repetição N. 1 em 2.7899048328399654 segundos.
# Iniciando Repetição N. 2
# Finalizada a Repetição N. 2 em 3.3208956638971956 segundos.
# Iniciando Repetição N. 3
# Finalizada a Repetição N. 3 em 3.3274488806724563 segundos.
# Iniciando Repetição N. 4
# Finalizada a Repetição N. 4 em 3.5218085169792173 segundos.
# Inicializando o modelo com os parâmetros:
# N = 500 - pa = 2 - mu = 360 - m = 5 - kappa = 10 - lambda = 10 - alpha = 0.7 - omega = 0.3 - gamma = 1
# Iniciando Repetição N. 0
# Finalizada a Repetição N. 0 em 3.622719387213392 segundos.
# Iniciando Repetição N. 1
# Finalizada a Repetição N. 1 em 3.3564935247103382 segundos.
# Iniciando Repetição N. 2
# Finalizada a Repetição N. 2 em 3.1908753832181262 segundos.
# Iniciando Repetição N. 3
# Finalizada a Repetição N. 3 em 3.5053375681241365 segundos.
# Iniciando Repetição N. 4
# Finalizada a Repetição N. 4 em 3.585569564501442 segundos.
# Inicializando o modelo com os parâmetros:
# N = 500 - pa = 2 - mu = 360 - m = 5 - kappa = 10 - lambda = 10 - alpha = 0.8 - omega = 0.2 - gamma = 1
# Iniciando Repetição N. 0
# Finalizada a Repetição N. 0 em 3.529047608375547 segundos.
# Iniciando Repetição N. 1
# Finalizada a Repetição N. 1 em 3.5904627283414174 segundos.
# Iniciando Repetição N. 2
# Finalizada a Repetição N. 2 em 3.2693427642186443 segundos.
# Iniciando Repetição N. 3
# Finalizada a Repetição N. 3 em 2.9234650969505314 segundos.
# Iniciando Repetição N. 4
# Finalizada a Repetição N. 4 em 2.907943769296008 segundos.
# Inicializando o modelo com os parâmetros:
# N = 500 - pa = 2 - mu = 360 - m = 5 - kappa = 10 - lambda = 10 - alpha = 0.9 - omega = 0.1 - gamma = 1
# Iniciando Repetição N. 0
# Finalizada a Repetição N. 0 em 3.1117263913154605 segundos.
# Iniciando Repetição N. 1
# Finalizada a Repetição N. 1 em 3.8785118699073755 segundos.
# Iniciando Repetição N. 2
# Finalizada a Repetição N. 2 em 3.439791997273766 segundos.
# Iniciando Repetição N. 3
# Finalizada a Repetição N. 3 em 3.304451497395835 segundos.
# Iniciando Repetição N. 4
# Finalizada a Repetição N. 4 em 3.3470263600349424 segundos.
# Inicializando o modelo com os parâmetros:
# N = 500 - pa = 2 - mu = 360 - m = 5 - kappa = 10 - lambda = 10 - alpha = 1.0 - omega = 0.0 - gamma = 1
# Iniciando Repetição N. 0
# Finalizada a Repetição N. 0 em 3.1446232597033186 segundos.
# Iniciando Repetição N. 1
# Finalizada a Repetição N. 1 em 3.0388666470845522 segundos.
# Iniciando Repetição N. 2
# Finalizada a Repetição N. 2 em 3.0272711078325893 segundos.
# Iniciando Repetição N. 3
# Finalizada a Repetição N. 3 em 2.99480495452881 segundos.
# Iniciando Repetição N. 4
# Finalizada a Repetição N. 4 em 3.1181963841120406 segundos.

# %%
stats = {'H':H, 'pi':pi}
name = 'Stats - (alpha, omega) in {} - lambda = {} - kappa = {}'.format(proportions, lambd, kappa)
with open ('Outputs/'+name, 'wb') as stats_file:
    pickle.dump(stats, stats_file)
    
name = 'Opinion Fragmentation - (alpha, omega) in {} - lambda = {} - kappa = {}'.format(proportions, lambd, kappa)
with open('Outputs/'+name, 'wb') as stats_file:
    pickle.dump(info_dist_stats, stats_file)

# %%
kappa = 0
# kappa = 10
# kappa = 20
num_repetitions = 1
seeds = [random.randint(1, 100) for i in range(num_repetitions)]
proportions = [(0.5, 0.5), (0.6, 0.4), (0.7, 0.3), (0.8, 0.2), (0.9, 0.1), (1.0, 0.0)]
# proportions = [(0.6, 0.0), (0.5, 0.1), (0.4, 0.2), (0.3, 0.3)]
# alpha = 0.5          # Proportion of individuals with tendency to increase polarity
# omega = 0.5          # Proportion of individuals with tendency to lower polarity
lambd = 5            # Polarization coefficient
# lambd = 10
# lambd = 15

T = 2000

gamma = 0         # Confidence factor
# gamma = 5
# gamma = -5

H = {str(prop):None for prop in proportions}
pi = {str(prop):None for prop in proportions}
info_dist_stats = {str(prop):{code:[] for code in A.keys()} for prop in proportions}
N = 500

for alpha, omega in proportions:
    
    print("Inicializando o modelo com os parâmetros:")
    print("N = {} - pa = {} - mu = {} - m = {} - kappa = {} - lambda = {} - alpha = {} - omega = {} - gamma = {}".format(N, pa, mu, m, kappa, lambd, alpha, omega, gamma))
    model = Model(N, pa, mu, m, kappa, lambd, alpha, omega, gamma, 0, False)
    
    H[str((alpha, omega))] = []
    pi[str((alpha, omega))] = []
    
    for rep in range(num_repetitions):
        H_rep_temp    = []
        Pi_rep_temp   = []
        D = deepcopy(A)
        for code in D.keys():
            D[code] = []
        # Especifica um valor inicial para o gerador de números pseudo-aleatórios e inicializa/reiniciar o modelo com esse gerador.
        seed = seeds[rep]
        model.seed = seed
        model.initialize_model_info()
        
        print("Iniciando Repetição N. {}".format(rep))
        elapsedTime = 0
        for i in range(T):
            elapsedTime += simulate(model)
            H_rep_temp.append(model.H)
            Pi_rep_temp.append(model.pi)
            D_temp = compute_opinion_fragmentation(model)
            for code in D.keys():
                D[code].append(D_temp[code])
            
        # Apende aos dados vinculados ao parâmetro "k" os valores de todas as repetições
        print("Finalizada a Repetição N. {} em {} segundos.".format(rep, elapsedTime))
        H[str((alpha, omega))].append(H_rep_temp)
        pi[str((alpha, omega))].append(Pi_rep_temp)
        for code in D.keys():   
            info_dist_stats[str((alpha, omega))][code].append(D[code])
    
# Tira a média das simulações para cada k
for prop in proportions:
    H[str(prop)] = mean_lists(H[str(prop)])
    pi[str(prop)] = mean_lists(pi[str(prop)])
    for code in info_dist_stats[str(prop)].keys():
        info_dist_stats[str(prop)][code] = mean_lists(info_dist_stats[str(prop)][code])
# Out:
# Inicializando o modelo com os parâmetros:
# N = 500 - pa = 2 - mu = 360 - m = 5 - kappa = 0 - lambda = 10 - alpha = 0.5 - omega = 0.5 - gamma = 0
# Iniciando Repetição N. 0
# Finalizada a Repetição N. 0 em 13.46286203861238 segundos.
# Inicializando o modelo com os parâmetros:
# N = 500 - pa = 2 - mu = 360 - m = 5 - kappa = 0 - lambda = 10 - alpha = 0.6 - omega = 0.4 - gamma = 0
# Iniciando Repetição N. 0
# Finalizada a Repetição N. 0 em 12.313724990685767 segundos.
# Inicializando o modelo com os parâmetros:
# N = 500 - pa = 2 - mu = 360 - m = 5 - kappa = 0 - lambda = 10 - alpha = 0.7 - omega = 0.3 - gamma = 0
# Iniciando Repetição N. 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-56959543c7c8> in <module>
#      46         elapsedTime = 0
#      47         for i in range(T):
# ---> 48             elapsedTime += simulate(model)
#      49             H_rep_temp.append(model.H)
#      50             Pi_rep_temp.append(model.pi)
#
# ~\Dropbox\Patrick\Programa\EntropiaGrafos\Scripts\Model.py in simulate(M)
#     212     end = time()
#     213
# --> 214     M.update_model()
#     215     return (end - start)/60
#     216
#
# ~\Dropbox\Patrick\Programa\EntropiaGrafos\Scripts\Model.py in update_model(self)
#      65     def update_model(self):
#      66         for node in self.G:
# ---> 67             self.update_node_info(node, update_memory = True)
#      68
#      69         # self.update_memory() #
#
# KeyboardInterrupt:

# %%
stats = {'H':H, 'pi':pi}
name = 'Stats - (alpha, omega) in {} - lambda = {} - kappa = {}'.format(proportions, lambd, kappa)
with open ('Outputs/'+name, 'wb') as stats_file:
    pickle.dump(stats, stats_file)
    
name = 'Opinion Fragmentation - (alpha, omega) in {} - lambda = {} - kappa = {}'.format(proportions, lambd, kappa)
with open('Outputs/'+name, 'wb') as stats_file:
    pickle.dump(info_dist_stats, stats_file)

# %%
print(15)
# Out:
# 15
