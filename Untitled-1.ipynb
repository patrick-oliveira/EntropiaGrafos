# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from opdynamics.components.utils import generate_random_samples

# %%
def generate_random_samples(
    n_samples: int,
    n_dimensions: int,
    seed: int = 0,
    distribution: str = "normal",
    **distribution_kwargs
) -> np.ndarray:
    np.random.seed(seed)
    match distribution:
        case "normal":
            return np.random.normal(size=(n_samples, n_dimensions))
        case "multivariate_normal":
            mean = distribution_kwargs.get("mean", np.zeros(n_dimensions))
            cov = distribution_kwargs.get("cov", np.eye(n_dimensions))
            return np.random.multivariate_normal(mean, cov, n_samples)
        case "uniform":
            return np.random.uniform(size=(n_samples, n_dimensions))
        case _:
            raise ValueError(f"Unknown distribution: {distribution}")

# %%
X = generate_random_samples(
    n_samples = 50,
    n_dimensions = 2,
    seed=0,
    distribution="multivariate_normal",
    mean=np.array([10, 0])
)

# %%
X
# Out:
# array([[11.76405235,  0.40015721],
#        [10.97873798,  2.2408932 ],
#        [11.86755799, -0.97727788],
#        [10.95008842, -0.15135721],
#        [ 9.89678115,  0.4105985 ],
#        [10.14404357,  1.45427351],
#        [10.76103773,  0.12167502],
#        [10.44386323,  0.33367433],
#        [11.49407907, -0.20515826],
#        [10.3130677 , -0.85409574],
#        [ 7.44701018,  0.6536186 ],
#        [10.8644362 , -0.74216502],
#        [12.26975462, -1.45436567],
#        [10.04575852, -0.18718385],
#        [11.53277921,  1.46935877],
#        [10.15494743,  0.37816252],
#        [ 9.11221425, -1.98079647],
#        [ 9.65208785,  0.15634897],
#        [11.23029068,  1.20237985],
#        [ 9.61267318, -0.30230275],
#        [ 8.95144703, -1.42001794],
#        [ 8.29372981,  1.9507754 ],
#        [ 9.49034782, -0.4380743 ],
#        [ 8.74720464,  0.77749036],
#        [ 8.38610215, -0.21274028],
#        [ 9.10453344,  0.3869025 ],
#        [ 9.48919486, -1.18063218],
#        [ 9.97181777,  0.42833187],
#        [10.06651722,  0.3024719 ],
#        [ 9.36567791, -0.36274117],
#        [ 9.32753955, -0.35955316],
#        [ 9.18685372, -1.7262826 ],
#        [10.17742614, -0.40178094],
#        [ 8.36980165,  0.46278226],
#        [ 9.09270164,  0.0519454 ],
#        [10.72909056,  0.12898291],
#        [11.13940068, -1.23482582],
#        [10.40234164, -0.68481009],
#        [ 9.12920285, -0.57884966],
#        [ 9.68844747,  0.05616534],
#        [ 8.83485016,  0.90082649],
#        [10.46566244, -1.53624369],
#        [11.48825219,  1.89588918],
#        [11.17877957, -0.17992484],
#        [ 8.92924738,  1.05445173],
#        [ 9.59682305,  1.22244507],
#        [10.20827498,  0.97663904],
#        [10.3563664 ,  0.70657317],
#        [10.01050002,  1.78587049],
#        [10.12691209,  0.40198936]])

# %%
from sklearn.neighbors import KernelDensity

# %%
kde = KernelDensity(bandwidth=1.0, kernel='gaussian').fit(X)

# %%
kde.sample(1)
# Out:
# array([[ 8.73298275, -0.50144844]])

# %%
new_samples = kde.sample(100)

# %%
np.exp(kde.score_samples(new_samples))
# Out:
# array([0.02106429, 0.06734595, 0.01313294, 0.06563006, 0.02089048,
#        0.02844808, 0.01910618, 0.00429835, 0.0713301 , 0.05895408,
#        0.01453933, 0.01134953, 0.07996847, 0.01435206, 0.05153395,
#        0.01380001, 0.07537697, 0.03371473, 0.05955046, 0.00474409,
#        0.01974277, 0.00513113, 0.06589747, 0.00664969, 0.05782981,
#        0.01119963, 0.02258273, 0.06227652, 0.03687487, 0.02744893,
#        0.0152039 , 0.05361113, 0.07846235, 0.05318428, 0.0569334 ,
#        0.07125462, 0.05314551, 0.02010948, 0.00340908, 0.06054262,
#        0.0219187 , 0.07714892, 0.01739042, 0.03794902, 0.02047534,
#        0.02072678, 0.05325966, 0.06402755, 0.03193378, 0.03023105,
#        0.01649402, 0.02258168, 0.01847434, 0.02619236, 0.0663336 ,
#        0.0643314 , 0.04232094, 0.05393111, 0.03773601, 0.05655569,
#        0.05076706, 0.01328146, 0.02379375, 0.04731956, 0.04100091,
#        0.04324936, 0.02320965, 0.04897459, 0.03932832, 0.04214769,
#        0.0600859 , 0.01881175, 0.01128078, 0.00644745, 0.02668335,
#        0.0395892 , 0.00241107, 0.02593427, 0.06272838, 0.03889719,
#        0.01897779, 0.01958407, 0.01891381, 0.02337976, 0.04840356,
#        0.07837785, 0.0067114 , 0.01017588, 0.04569063, 0.03235392,
#        0.0583349 , 0.07022663, 0.02963103, 0.05964284, 0.04957485,
#        0.06429968, 0.0514415 , 0.01748865, 0.01018196, 0.07050335])

# %%
fig, ax = plt.subplots(figsize = (5, 5))
ax.set_xlim(-15, 15)
ax.set_ylim(-15, 15)

ax.scatter(X[:, 0], X[:, 1], color='red', label='X')
ax.scatter(new_samples[:, 0], new_samples[:, 1], color='blue', label='new samples')

# %%
fig, ax = plt.subplots(figsize = (5, 5))
ax.set_xlim(-15, 15)
ax.set_ylim(-15, 15)


ax.scatter(X[:, 0], X[:, 1], color="red", label="X")
ax.scatter(Y[:, 0], Y[:, 1], color="blue", label="Y")
ax.scatter(Z[:, 0], Z[:, 1], color="green", label="Z")
ax.scatter(W[:, 0], W[:, 1], color="orange", label="W")

ax.legend()

# %%
from KDEpy import FFTKDE

# %%
kde = FFTKDE(kernel='box', norm=2)

grid_points = 2**7

grid, points = kde.fit(Z).evaluate(grid_points)
points = points / np.sum(points)
x, y = np.unique(grid[:, 0]), np.unique(grid[:, 1])
z = points.reshape(grid_points, grid_points).T

# %%
fig, ax = plt.subplots(figsize = (5, 5))


ax.contour(x, y, z, 16, linewidths=0.8, colors='k')
ax.contourf(x, y, z, 16, cmap="RdBu_r")
ax.plot(Z[:, 0], Z[:, 1], 'ok', ms=3)

# %%
points.max()
# Out:
# np.float64(0.00044271549326304325)

# %%
points.min()
# Out:
# np.float64(1.1069680725636903e-18)

# %%
# compute entropy from points
from scipy.stats import entropy

entropy(points)
# Out:
# np.float64(8.662091733418595)

# %%
kde = FFTKDE(kernel='box', norm=2)
grid_points = 2**7


grid_x, points_x = kde.fit(X).evaluate(grid_points)
grid_y, points_y = kde.fit(Y).evaluate(grid_points)
grid_z, points_z = kde.fit(Z).evaluate(grid_points)
grid_w, points_w = kde.fit(W).evaluate(grid_points)

# %%
entropy(points_x), entropy(points_y), entropy(points_z), entropy(points_w)
# Out:
# (np.float64(8.907571320991806),
#  np.float64(8.801913743162045),
#  np.float64(8.662091733418595),
#  np.float64(8.8337310052936))

# %%
def shannon_entropy(P: np.ndarray) -> float:
    """
    Calculate the Shannon entropy of a probability distribution.

    Parameters:
    P (np.ndarray): The probability distribution.

    Returns:
    np.ndarray: The Shannon entropy of the probability distribution.
    """
    return - (P * np.log(P)).sum()


from scipy.special import kl_div

# %%
var = 1
mean_x = np.array([1, 1])
mean_y = np.array([5, 5])

X = generate_random_samples(
    n_samples = 1000,
    n_dimensions = 2,
    seed=0,
    distribution="multivariate_normal",
    mean=mean_x,
    cov = np.array([[var, 0], [0, var]])
)

# Y = generate_random_samples(
#     n_samples = 1000,
#     n_dimensions = 2,
#     seed = 1,
#     distribution = "uniform"
# )

Y = generate_random_samples(
    n_samples = 1000,
    n_dimensions = 2,
    seed=0,
    distribution="multivariate_normal",
    mean=mean_y,
    cov = np.array([[0, 0], [0, 0]])
)

kde = FFTKDE(kernel='box', norm=2)

grid_points = 2**7

_, points_x = kde.fit(X).evaluate(grid_points)
_, points_y = kde.fit(Y).evaluate(grid_points)

entropy(points_x), entropy(points_y)
# Out:
# (np.float64(8.561683248001135), np.float64(9.457409345940222))

# %%
px = points_x / np.sum(points_x)
py = points_y / np.sum(points_y)
M_dist = (px + py) / 2

# %%
1 - (entropy(M_dist) - (shannon_entropy(px) + shannon_entropy(py)) / 2)
# Out:
# np.float64(0.773049330301669)

# %%
d = sqrt(x^2 + y^2)

exp(- d)

# %%
def radial_f(r, epsilon):
    # return 1 - (1 / (1 + (epsilon*r)**2))
    return np.exp(-epsilon*r)

def distance_f(x, y, epsilon: float = 1):
    dif = x - y
    distance = np.sqrt(np.sum(dif**2))

    return radial_f(distance, epsilon)

# %%
Rs = np.linspace(0, 2, 1000)

epsilons = np.linspace(1, 5, 5)

fig, ax = plt.subplots(figsize = (5, 5))
# x label
ax.set_xlabel("r")
ax.set_ylabel("f(r)")

for e in epsilons:
    ax.plot(Rs, [radial_f(r, e) for r in Rs], label=f"epsilon = {e}")

ax.legend()

# %%
radial_f(1, 10)
# Out:
# np.float64(4.5399929762484854e-05)

# %%
distance_f(np.array([0, 0]), np.array([1, 1]), 10)
# Out:
# np.float64(7.213541526967138e-07)

# %%
x = np.random.normal(size = (1, 2))
y = np.random.normal(size = (1, 2))

fig, ax = plt.subplots(figsize = (5, 5))
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.plot(x[0, 0], x[0, 1], 'o', label="x")
ax.plot(y[0, 0], y[0, 1], 'o', label="y")
ax.legend()

distance_f(x, y, 0.55)
# Out:
# np.float64(0.6711145812978734)

# %%
radial_f(1, 3)
# Out:
# np.float64(0.049787068367863944)

# %%
n = 100000
X = np.random.normal(size = (n, 2))
Y = np.random.normal(size = (n, 2))


distances = []

for i in range(n):
    distances.append(distance_f(X[i], Y[i], 0.25))

# %%
g(X, Y)

g = exp(-epsilon * norm(x - y))

g = 1 / (1 + (x - y)**2)

# %%
_ = plt.hist(distances, bins=100)

# %%
var = 5
mean_x = np.array([1, 1])
mean_y = np.array([0, 1])

X = generate_random_samples(
    n_samples = 1000,
    n_dimensions = 2,
    seed=0,
    distribution="multivariate_normal",
    mean=mean_x,
    cov = np.array([[var, 0], [0, var]])
)

# Y = generate_random_samples(
#     n_samples = 1000,
#     n_dimensions = 2,
#     seed = 1,
#     distribution = "uniform"
# )

Y = generate_random_samples(
    n_samples = 1000,
    n_dimensions = 2,
    seed=0,
    distribution="multivariate_normal",
    mean=mean_y,
    cov = np.array([[0, 0], [0, 0]])
)

kde = FFTKDE(kernel='box', norm=2)

grid_points = 2**7

_, points_x = kde.fit(X).evaluate(grid_points)
_, points_y = kde.fit(Y).evaluate(grid_points)

px = points_x / np.sum(points_x)
py = points_y / np.sum(points_y)
M_dist = (px + py) / 2

entropy(points_x), entropy(points_y)
# Out:
# (np.float64(8.577864662147675), np.float64(9.457409345940222))

# %%
jsd = 1 - (entropy(M_dist) - (shannon_entropy(px) + shannon_entropy(py)) / 2)
mean_dif = distance_f(mean_x, mean_y, 0.55)

p = 0.5
jsd, mean_dif, p*jsd + (1-p)*mean_dif
# Out:
# (np.float64(0.7807069629572219),
#  np.float64(0.5769498103804866),
#  np.float64(0.6788283866688543))
