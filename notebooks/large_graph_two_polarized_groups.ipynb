# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
import pickle
import os 

sys.path.append("..")

from opdynamics.utils.reading_tools import (parse_experiment_params,
                                            make_tuple,
                                            count_experiment_runs,
                                            get_runs_paths)
from opdynamics.utils.results_tools import get_experiment_mean_data
from opdynamics.utils.plotting.formatting import (classical_structure,
                                                  format_text)
from opdynamics.utils.plotting.plotting import heat_plot

# %%
base_path = "../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0"
folders = os.listdir(base_path)
folders = [base_path + "/" + f for f in folders]
for folder in folders:
    files = os.listdir(folder)
    for f in files:
        f_path = folder + "/" + f
        if ".attrs" in f:
            os.remove(f_path)

# %%
a = pickle.load(open("../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0/d3a1be83039e64efd8c458a81ac325554b36124a58d873646fcca68cd6b403dd/run_25_stats.pkl", "rb"))

# %%
a.keys()
# Out:
# dict_keys(['Entropy', 'Proximity', 'Polarity'])

# %%
params = parse_experiment_params("../experiments_params/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform.json")
results = get_experiment_mean_data(params, "../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/")
# Out:
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/d1a7b59e4a73d78400a7dc37bc90f2d2157cc2ccd2e3137f08cb5f30ad08032b/run_17_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/d1a7b59e4a73d78400a7dc37bc90f2d2157cc2ccd2e3137f08cb5f30ad08032b/run_15_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/d1a7b59e4a73d78400a7dc37bc90f2d2157cc2ccd2e3137f08cb5f30ad08032b/run_14_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/d1a7b59e4a73d78400a7dc37bc90f2d2157cc2ccd2e3137f08cb5f30ad08032b/run_16_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/7d4c11be70fb188675bf510a7638e9a59684a8171ae334bd13347209841e4060/run_13_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/7d4c11be70fb188675bf510a7638e9a59684a8171ae334bd13347209841e4060/run_17_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/7d4c11be70fb188675bf510a7638e9a59684a8171ae334bd13347209841e4060/run_18_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/7d4c11be70fb188675bf510a7638e9a59684a8171ae334bd13347209841e4060/run_15_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/7d4c11be70fb188675bf510a7638e9a59684a8171ae334bd13347209841e4060/run_14_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/7d4c11be70fb188675bf510a7638e9a59684a8171ae334bd13347209841e4060/run_16_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/8d5585fd64539bd1802d73ebf29b64771d5390d13ed10825152d0981c098cba1/run_23_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/89d189a2f28722195a3e30a4b7f8d8b2370352113279db28771d220c663c8a97/run_32_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/89d189a2f28722195a3e30a4b7f8d8b2370352113279db28771d220c663c8a97/run_28_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/89d189a2f28722195a3e30a4b7f8d8b2370352113279db28771d220c663c8a97/run_26_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/89d189a2f28722195a3e30a4b7f8d8b2370352113279db28771d220c663c8a97/run_33_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/89d189a2f28722195a3e30a4b7f8d8b2370352113279db28771d220c663c8a97/run_29_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/89d189a2f28722195a3e30a4b7f8d8b2370352113279db28771d220c663c8a97/run_27_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/89d189a2f28722195a3e30a4b7f8d8b2370352113279db28771d220c663c8a97/run_25_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/89d189a2f28722195a3e30a4b7f8d8b2370352113279db28771d220c663c8a97/run_31_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/89d189a2f28722195a3e30a4b7f8d8b2370352113279db28771d220c663c8a97/run_30_stats.pkl
# ../results/large_graph_two_polarized_group_no_neutral_kappa_0_25_lambda_0_uniform/6b12b11063ce4e93545dda84c57ff0980ba6a8b658ffbc8302a9560de15c38a0/run_29_stats.pkl

# %%
# parameters

nrows = 2
ncols = 2

titles = [
    r"$\lambda = 0, \kappa = 0$",
    r"$\lambda = 0, \kappa = 25$",
    r"$\lambda = 0, \kappa = 0$",
    r"$\lambda = 0, \kappa = 25$"
]
title_size = 15
single_ylabel = True
position_ylabel = "left"
ylabel = ""
ylabel_fontsize = 15
xlabel_bottom_only = True
xlabel = r"Iteration $T$"
xlabel_fontsize = 15
axis_width = 1.08
tick_pad = 8
tick_label_size = 17
num_x_ticks = 3
num_y_ticks= 3


fig, axs = plt.subplots(nrows = nrows, ncols = ncols, figsize = (5*ncols, 5*nrows))
fig.subplots_adjust(wspace = 0.3)

fig, axs = classical_structure(
    fig,
    axs,
    axis_width,
    tick_pad,
    tick_label_size,
    num_x_ticks,
    num_y_ticks
)

# Text
fig, axs = format_text(
    fig,
    axs,
    titles,
    title_size,
    single_ylabel,
    position_ylabel,
    ylabel,
    ylabel_fontsize,
    xlabel_bottom_only,
    xlabel,
    xlabel_fontsize
)

axs[0][0].set_ylabel(r"$\overline{H}$")
axs[0][1].set_ylabel(r"$\overline{H}$")
axs[1][0].set_ylabel(r"$\overline{\pi}$")
axs[1][1].set_ylabel(r"$\overline{\pi}$")

# plot
line_width = 2

alpha_omega_color =  {
    (0.8, 0.2): "purple",
    (0.6, 0.4): "#32BD68",
    (0.5, 0.5): "black",
    (0.6, 0.2): "y",
    (0.4, 0.4): "g",
    (0.5, 0.2): "k",
    (0.5, 0.4): "r"
}

X = np.arange(1, 500 + 1)

valid_combinations = {(0.8, 0.2), (0.6, 0.4), (0.5, 0.5)}

selected_params = [
    x for x in params if
    x["kappa"] == 0 and x["lambd"]  == 0
    and (x["alpha"], x["omega"]) in valid_combinations
]
for p in selected_params:
    axs[0][0].plot(
        X,
        results[make_tuple(p, True)]["entropy"],
        c = alpha_omega_color[(p["alpha"], p["omega"])],
        linewidth = line_width,
        label = r"$\alpha = {}, \omega = {}$".format(p["alpha"], p["omega"])
    )

selected_params = [
    x for x in params if
    x["kappa"] == 25 and x["lambd"]  == 0
    and (x["alpha"], x["omega"]) in valid_combinations
]
for p in selected_params:
    axs[0][1].plot(
        X,
        results[make_tuple(p, True)]["entropy"],
        c = alpha_omega_color[(p["alpha"], p["omega"])],
        linewidth = line_width,
        label = r"$\alpha = {}, \omega = {}$".format(p["alpha"], p["omega"])
    )

selected_params = [
    x for x in params if
    x["kappa"] == 0 and x["lambd"]  == 0
    and (x["alpha"], x["omega"]) in valid_combinations
]
for p in selected_params:
    axs[1][0].plot(
        X,
        results[make_tuple(p, True)]["polarity"],
        c = alpha_omega_color[(p["alpha"], p["omega"])],
        linewidth = line_width,
        label = r"$\alpha = {}, \omega = {}$".format(p["alpha"], p["omega"])
    )

selected_params = [
    x for x in params if
    x["kappa"] == 25 and x["lambd"]  == 0
    and (x["alpha"], x["omega"]) in valid_combinations
]
for p in selected_params:
    axs[1][1].plot(
        X,
        results[make_tuple(p, True)]["polarity"],
        c = alpha_omega_color[(p["alpha"], p["omega"])],
        linewidth = line_width,
        label = r"$\alpha = {}, \omega = {}$".format(p["alpha"], p["omega"])
    )


axs[1][0].legend(loc = 'lower right', fontsize = 15)

# %%
from matplotlib.ticker import MaxNLocator

nrows = 1
ncols = 2

titles = [
    r"$\lambda = 0, \kappa = 0, \alpha = 0.8, \omega = 0.2$",
    r"$\lambda = 0, \kappa = 0, \alpha = 0.5, \omega = 0.5$"
]
title_size = 15
single_ylabel = True
position_ylabel = "left"
ylabel = ""
ylabel_fontsize = 15
xlabel_bottom_only = True
xlabel = ""
xlabel_fontsize = 15
axis_width = 1.08
tick_pad = 8
tick_label_size = 17
num_x_ticks = 3
num_y_ticks= 3


fig, axs = plt.subplots(nrows = nrows, ncols = ncols, figsize = (5*ncols, 5*nrows))
fig, axs = classical_structure(
    fig,
    axs,
    axis_width,
    tick_pad,
    tick_label_size,
    num_x_ticks,
    num_y_ticks
)
fig, axs = format_text(
    fig,
    axs,
    titles,
    title_size,
    single_ylabel,
    position_ylabel,
    ylabel,
    ylabel_fontsize,
    xlabel_bottom_only,
    xlabel,
    xlabel_fontsize
)

# ************
mins = []
maxs = []



param = selected_params = [x for x in params if x['kappa'] == 0 and x['lambd'] == 0 and x['alpha'] == 0.8 and x["omega"] == 0.2].pop()
data = results[make_tuple(param, True)]
maxs.append(data['distribution'][:500].max())
mins.append(data['distribution'][:500].min())
_, ax = heat_plot(data['distribution'][:500], cmap = 'viridis', fig = fig, ax = axs[0], vmax = 0.2)

axs[0].set_ylabel("Information")
axs[0].set_xlabel(r"Iteration $T$")

axs[0].tick_params(
    which = 'both',
    top = False,
    right = False,
    labelsize = 10
)

axs[0].xaxis.set_major_locator(MaxNLocator(5))
new_tick_locations = axs[0].get_xticks()
ticks = [int(x) for x in new_tick_locations]
axs[0].set_xticks(new_tick_locations)
axs[0].set_xticklabels(ticks, rotation = 45)




param = selected_params = [x for x in params if x['kappa'] == 0 and x['lambd'] == 0 and x['alpha'] == 0.5 and x["omega"] == 0.5].pop()
data = results[make_tuple(param, True)]
maxs.append(data['distribution'][:500].max())
mins.append(data['distribution'][:500].min())
_, ax = heat_plot(data['distribution'][:500], cmap = 'viridis', fig = fig, ax = axs[1], vmax = 0.2)

# axs[1].set_ylabel("Information (Decimal)")
axs[1].set_xlabel(r"Iteration $T$")

axs[1].tick_params(
    which = 'both',
    top = False,
    right = False,
    labelsize = 10
)

axs[1].xaxis.set_major_locator(MaxNLocator(5))
new_tick_locations = axs[1].get_xticks()
ticks = [int(x) for x in new_tick_locations]
axs[1].set_xticks(new_tick_locations)
axs[1].set_xticklabels(ticks, rotation = 45)


from matplotlib.colors import Normalize
import matplotlib.cm as cm
cbar_ax = fig.add_axes([0.92, 0.115, 0.04, 0.76])
cbar = fig.colorbar(
    cm.ScalarMappable(norm = Normalize(
        np.round(np.min(mins), 1),
        np.round(np.max(maxs), 1))
    ),
    cax = cbar_ax
)
