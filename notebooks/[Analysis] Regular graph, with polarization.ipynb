# %%
import pickle
import os
import numpy as np
import matplotlib.pyplot as plt

from itertools import product
from pathlib import Path
from typing import Tuple

# %%
def get_runs(path: str):
    return [x for x in os.listdir(path) if "run" in x]

# %%
params = [x for x in os.listdir('.') if '(' in x]

# %%
mean_stats = {}
kappas = [0, 15, 30]
gammas = [-10, 0, 10]
degree = [5, 15, 30]
lambd = [0, 0.1, 0.3, 1, 5]
alpha = [1, 0.8, 0.6, 0.4, 0.2]
omega = [0, 0.2, 0.4, 0.6, 0.8]


for k, g, d, l, a, o in product(kappas, gammas, degree, lambd, alpha, omega):
    param = ("regular", 50, 160, 1, k, l, a, o, g, d, 2)
    input_path = Path(str(param))
    try:
        runs = get_runs(str(param))
    except:
        continue
    
    mean_run_stats = {
        "Entropy": np.zeros(100),
        "Proximity": np.zeros(100),
        "Polarity": np.zeros(100)
    }

    num_runs = len(runs)
    for run in runs:
        stats = pickle.load(open(input_path / run, "rb"))
        mean_run_stats['Entropy'] += stats['Entropy']
        mean_run_stats['Proximity'] += stats['Proximity']
        mean_run_stats['Polarity'] += stats['Polarity']

    mean_run_stats['Entropy'] /= num_runs
    mean_run_stats['Proximity'] /= num_runs
    mean_run_stats['Polarity'] /= num_runs
    
    mean_stats[param] = mean_run_stats

# %%
len(mean_stats.keys())
# Out:
# 2685

# %% [markdown]
# ### 1 grupo polarizado X grupo neutro

# %%
fig, axs = plt.subplots(nrows = 3, ncols = 3, figsize = (15, 10))
fig.subplots_adjust(wspace = 0.18)
for ax in axs[2]:
    ax.set_xlabel("T", fontsize = 25)
    
colors = {
    1: "purple",
    0.8: "darkgreen",
    0.6: "lightblue",
    0.4: "y",
    0.2: "k"
}

style = {
    0: '--',
    15: '-',
    30: ':'
}
alpha = [1, 0.8, 0.6, 0.4, 0.2]
degree = [5, 15, 30]


for i in range(len(alpha)):
    for k in range(len(degree)):
        for j in range(len(kappas)):
            param = ("regular", 50, 160, 1, kappas[j], 0, alpha[i], 0, 0, degree[k], 2)

            results = mean_stats[param]
            mean_entropy = results['Entropy']
            X = range(len(mean_entropy))

            axs[j][k].plot(X, mean_entropy, label = f'A = {alpha[i]}', color = colors[alpha[i]], linewidth = 5)

            axs[j][k].set_title(f"Degree {degree[k]}, K = {kappas[j]}")
            
axs[0][2].legend(fontsize = 10, loc = 1)

# %%
fig, axs = plt.subplots(nrows = 3, ncols = 3, figsize = (15, 10))
fig.subplots_adjust(wspace = 0.18)
for ax in axs[2]:
    ax.set_xlabel("T", fontsize = 25)
    
colors = {
    1: "purple",
    0.8: "darkgreen",
    0.6: "lightblue",
    0.4: "y",
    0.2: "k"
}

style = {
    0: '--',
    15: '-',
    30: ':'
}
alpha = [1, 0.8, 0.6, 0.4, 0.2]
degree = [5, 15, 30]


for i in range(len(alpha)):
    for k in range(len(degree)):
        for j in range(len(kappas)):
            param = ("regular", 50, 160, 1, kappas[j], 0.1, alpha[i], 0, 0, degree[k], 2)

            results = mean_stats[param]
            mean_entropy = results['Entropy']
            X = range(len(mean_entropy))

            axs[j][k].plot(X, mean_entropy, label = f'A = {alpha[i]}', color = colors[alpha[i]], linewidth = 5)

            axs[j][k].set_title(f"Degree {degree[k]}, K = {kappas[j]}")
            
axs[0][2].legend(fontsize = 10, loc = 1)

# %%
fig, axs = plt.subplots(nrows = 3, ncols = 3, figsize = (15, 10))
fig.subplots_adjust(wspace = 0.18)
for ax in axs[2]:
    ax.set_xlabel("T", fontsize = 25)
    
colors = {
    1: "purple",
    0.8: "darkgreen",
    0.6: "lightblue",
    0.4: "y",
    0.2: "k"
}

style = {
    0: '--',
    15: '-',
    30: ':'
}
alpha = [1, 0.8, 0.6, 0.4, 0.2]
degree = [5, 15, 30]


for i in range(len(alpha)):
    for k in range(len(degree)):
        for j in range(len(kappas)):
            param = ("regular", 50, 160, 1, kappas[j], 0.3, alpha[i], 0, 0, degree[k], 2)

            results = mean_stats[param]
            mean_entropy = results['Entropy']
            X = range(len(mean_entropy))

            axs[j][k].plot(X, mean_entropy, label = f'A = {alpha[i]}', color = colors[alpha[i]], linewidth = 5)

            axs[j][k].set_title(f"Degree {degree[k]}, K = {kappas[j]}")
            
axs[0][2].legend(fontsize = 10, loc = 1)

# %%
fig, axs = plt.subplots(nrows = 3, ncols = 3, figsize = (15, 10))
fig.subplots_adjust(wspace = 0.18)
for ax in axs[2]:
    ax.set_xlabel("T", fontsize = 25)
    
colors = {
    1: "purple",
    0.8: "darkgreen",
    0.6: "lightblue",
    0.4: "y",
    0.2: "k"
}

style = {
    0: '--',
    15: '-',
    30: ':'
}
alpha = [1, 0.8, 0.6, 0.4, 0.2]
degree = [5, 15, 30]


for i in range(len(alpha)):
    for k in range(len(degree)):
        for j in range(len(kappas)):
            param = ("regular", 50, 160, 1, kappas[j], 1, alpha[i], 0, 0, degree[k], 2)

            results = mean_stats[param]
            mean_entropy = results['Entropy']
            X = range(len(mean_entropy))

            axs[j][k].plot(X, mean_entropy, label = f'A = {alpha[i]}', color = colors[alpha[i]], linewidth = 5)

            axs[j][k].set_title(f"Degree {degree[k]}, K = {kappas[j]}")
            
axs[0][2].legend(fontsize = 10, loc = 1)

# %%
fig, axs = plt.subplots(nrows = 3, ncols = 3, figsize = (15, 10))
fig.subplots_adjust(wspace = 0.18)
for ax in axs[2]:
    ax.set_xlabel("T", fontsize = 25)
    
colors = {
    1: "purple",
    0.8: "darkgreen",
    0.6: "lightblue",
    0.4: "y",
    0.2: "k"
}

style = {
    0: '--',
    15: '-',
    30: ':'
}
alpha = [1, 0.8, 0.6, 0.4, 0.2]
degree = [5, 15, 30]


for i in range(len(alpha)):
    for k in range(len(degree)):
        for j in range(len(kappas)):
            param = ("regular", 50, 160, 1, kappas[j], 5, alpha[i], 0, 0, degree[k], 2)

            results = mean_stats[param]
            mean_entropy = results['Entropy']
            X = range(len(mean_entropy))

            axs[j][k].plot(X, mean_entropy, label = f'A = {alpha[i]}', color = colors[alpha[i]], linewidth = 5)

            axs[j][k].set_title(f"Degree {degree[k]}, K = {kappas[j]}")
            
axs[0][2].legend(fontsize = 10, loc = 1)

# %% [markdown]
# ### grupo polarizado A X grupo polarizado B x grupo neutro

# %% [markdown]
# ### grupo polarizado A X grupo polarizado B
